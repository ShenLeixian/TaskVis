# %%
#request data columns
import requests
headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/87.0.4280.67 Safari/537.36 Edg/87.0.664.47'}
url='http://localhost:8888/api/columns?dataset=movies'
req = requests.get(url, headers=headers) # 请求连接
req.content
# Out:
# b'[]'

# %%
#commbination recommendation
import requests
import json

url = "http://183.173.194.169:8888/api/Reco"
task=['characterize_distribution','find_extremum']
ColumnTypes=[
        # {"field": "Name", "type": "nominal"},
        # {"field": "Miles_per_Gallon", "type": "quantitative"},
        {"field": "Horsepower", "type": "quantitative"},
        # {'field': 'Weight_in_lbs', 'type': 'quantitative'},
        # {'field': 'Acceleration', 'type': 'quantitative'},
        {'field': 'Year', 'type': 'temporal'},
        # {'field': 'Origin', 'type': 'nominal'},
        # {"field": "Cylinders", "type": "ordinal"},
        {"field": "Displacement", "type": "quantitative"},
    ]
# url = ''.join([host,endpoint])
data = {
    "dataset": "cars",
    "ColumnTypes":ColumnTypes,
    "task":task,
    "mode":5
}

r = requests.post(url,json=data)
r.content
# Out:
# b'Internal Server Error\r\n\r\nThe server encountered an unexpected internal server error\r\n\r\n(generated by waitress)'

# %%
#individual recommendation
import requests
import json

url = "http://183.173.194.169:8888/api/Reco"
task=['characterize_distribution','find_extremum']
ColumnTypes=[
        # {"field": "Name", "type": "nominal"},
        # {"field": "Miles_per_Gallon", "type": "quantitative"},
        {"field": "Horsepower", "type": "quantitative"},
        # {'field': 'Weight_in_lbs', 'type': 'quantitative'},
        # {'field': 'Acceleration', 'type': 'quantitative'},
        {'field': 'Year', 'type': 'temporal'},
        # {'field': 'Origin', 'type': 'nominal'},
        # {"field": "Cylinders", "type": "ordinal"},
        {"field": "Displacement", "type": "quantitative"},
    ],
# url = ''.join([host,endpoint])
data = {
    "dataset": "cars",
    "ColumnTypes":ColumnTypes,
    "task":task,
    "mode":2
}

r = requests.post(url,json=data)
r.content
# Out:
# b'Internal Server Error\r\n\r\nThe server encountered an unexpected internal server error\r\n\r\n(generated by waitress)'
